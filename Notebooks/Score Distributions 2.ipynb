# %% [markdown]
# # Looking into the score distributions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def load_scores(model_name, component):
    filepath = f'../Models/{model_name}/savedModels/{model_name}_Yelp_{component}_7135User.npy'
    return np.load(filepath)

# %% [markdown]
# ### GeoSoCa

# %%
AKDE = load_scores('GeoSoCa', 'AKDE')
print(f"AKDE: {AKDE.shape}")
CC = load_scores('GeoSoCa', 'CC')
print(f"CC: {CC.shape}")
SC = load_scores('GeoSoCa', 'SC')
print(f"SC: {SC.shape}")
# Out:
# AKDE: (7135, 16621)
# CC: (7135, 16621)
# SC: (7135, 16621)

# %%
# AKDEflat = AKDE.ravel()
# AKDEflat = AKDEflat[AKDEflat != 0]
AKDEplot = np.log10(AKDEflat / AKDEflat.max())
AKDEplot = AKDEplot[~np.isinf(AKDEplot)]
print(AKDEplot.shape)
sns.distplot(AKDEplot, kde=False)
# Out:
# /tmp/ipykernel_22754/3600291756.py:3: RuntimeWarning: divide by zero encountered in log10
#   AKDEplot = np.log10(AKDEflat / AKDEflat.max())
# /tmp/ipykernel_22754/3600291756.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(AKDEplot, kde=False)
# (59009629,)
# <Axes: >

# %%
CCflat = CC.ravel()
CCflat = CCflat[CCflat != 0]
CCplot = np.log10(CCflat / CCflat.max())
CCplot = CCplot[~np.isinf(CCplot)]
print(CCplot.shape)
sns.distplot(CCplot, kde=False)
# Out:
# (96561888,)
# /tmp/ipykernel_22754/1376118013.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCplot, kde=False)
# <Axes: >

# %%
SCflat = SC.ravel()
SCflat = SCflat[SCflat != 0]
SCplot = np.log10(SCflat / SCflat.max())
SCplot = SCplot[~np.isinf(SCplot)]
print(SCplot.shape)
sns.distplot(SCplot, kde=False)
# Out:
# (4347746,)
# /tmp/ipykernel_22754/4162602359.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SCplot, kde=False)
# <Axes: >

# %% [markdown]
# ### LORE

# %%
AMC = load_scores('LORE', 'AMC')
print(f"AMC: {AMC.shape}")
FCF = load_scores('LORE', 'FCF')
print(f"FCF: {FCF.shape}")
KDE = load_scores('LORE', 'KDE')
print(f"KDE: {KDE.shape}")
# Out:
# AMC: (7135, 16621)
# FCF: (7135, 16621)
# KDE: (7135, 16621)

# %%
AKDEflat = AKDE.ravel()
AKDEflat = AKDEflat[AKDEflat != 0]
AKDEplot = np.log10(AKDEflat / AKDEflat.max())
AKDEplot = AKDEplot[~np.isinf(AKDEplot)]
print(AKDEplot.shape)
sns.distplot(AKDEplot, kde=False)
# Out:
# /tmp/ipykernel_22754/3600291756.py:3: RuntimeWarning: divide by zero encountered in log10
#   AKDEplot = np.log10(AKDEflat / AKDEflat.max())
# /tmp/ipykernel_22754/3600291756.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(AKDEplot, kde=False)
# (59009629,)
# <Axes: >

# %%
AKDEflat = AKDE.ravel()
AKDEflat = AKDEflat[AKDEflat != 0]
AKDEplot = np.log10(AKDEflat / AKDEflat.max())
AKDEplot = AKDEplot[~np.isinf(AKDEplot)]
print(AKDEplot.shape)
sns.distplot(AKDEplot, kde=False)
# Out:
# /tmp/ipykernel_22754/3600291756.py:3: RuntimeWarning: divide by zero encountered in log10
#   AKDEplot = np.log10(AKDEflat / AKDEflat.max())
# /tmp/ipykernel_22754/3600291756.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(AKDEplot, kde=False)
# (59009629,)
# <Axes: >

# %% [markdown]
# ### USG

# %%
U = load_scores('USG', 'U')
print(f"U: {U.shape}")
S = load_scores('USG', 'S')
print(f"S: {S.shape}")
G = load_scores('USG', 'G')
print(f"G: {G.shape}")
# Out:
# U: (7135, 16621)
# S: (7135, 16621)
# G: (7135, 16621)

# %%
Uflat = U.ravel()
Uflat = Uflat[Uflat != 0]
print(Uflat.shape)
sns.distplot(np.log10(Uflat / Uflat.max()), kde=False)
# Out:
# (42340439,)
# /tmp/ipykernel_1560/1867409342.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log10(Uflat / Uflat.max()), kde=False)
# <Axes: >

# %%
Sflat = S.ravel()
Sflat = Sflat[Sflat != 0]
Sflat_max = Sflat.max()
print(Sflat.shape)
sns.distplot(np.log10(Sflat / Sflat_max), kde=False)
# Out:
# (1323581,)
# /tmp/ipykernel_1560/1289523016.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log10(Sflat / Sflat_max), kde=False)
# <Axes: >

# %% [markdown]
# S was bugged, i guess it wasn't super important lmao

# %%
Gflat = G.ravel()
Gflat = Gflat[Gflat != 0]
Gflat_max = Gflat.max()
print(Gflat.shape)
sns.distplot(np.log10(Gflat / Gflat_max), kde=False)
# Out:
# (109962599,)
# /tmp/ipykernel_1560/2378610652.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log10(Gflat / Gflat_max), kde=False)
# <Axes: >

# %% [markdown]
# Notes
#
# * They seem mostly log-normal
# * A weighted sum might be weird
# * If we add in a secondary context, what form would it take?

# %% [markdown]
# ## Creating an item exposure fusion module

# %%
from Data.loadDatasetFiles import loadDatasetFiles
from Data.readDataSizes import readDataSizes
from Models.utils import readTrainingData

datasetFiles = loadDatasetFiles('Yelp')
dataDictionary = readDataSizes('Yelp', datasetFiles)
users, pois = dataDictionary['users'], dataDictionary['pois']
trainingMatrix, userCheckinCounts, poiCheckinCounts = readTrainingData(datasetFiles['train'], users['count'], pois['count'], False)
# Out:
# Loading Yelp dataset files ...
# Yelp dataset files have been loaded for processing!
# Reading the 'dataSize' file to prepare further processing...
# Yelp dataset contains 7135 users, 16621 locations, and 595 categories!
# Reading training data...
# Setting threshold to median repeating POI ratio of 0.7
# Setting threshold to 80th prc. of POI visits of 66.0

# %%
poiCheckinCounts.head()
# Out:
#         checkins  short_head
# poi_id
# 196         1596        True
# 3170        1297        True
# 1515        1277        True
# 1092        1085        True
# 1582        1085        True

# %%
sns.histplot(poiCheckinCounts.checkins)
# Out:
# <Axes: xlabel='checkins', ylabel='Count'>

# %%
xs = np.arange(0, 1600, 10)

# %%
poiCheckinCounts.checkins.max()
# Out:
# 1596

# %%
# binning
poiHist = poiCheckinCounts.groupby('checkins')[['short_head']].count().rename(columns={'short_head': 'frequency'}).sort_values(by='frequency', ascending=False)
poiHist = poiHist.reset_index()
poiHist.head()
# Out:
#    checkins  frequency
# 0         4        868
# 1         5        669
# 2         3        488
# 3         8        390
# 4         9        373

# %%
freqs, bins = np.histogram(poiCheckinCounts['checkins'], bins=xs)
bins = bins[1:]
nonzero = (freqs != 0)

# %%
x = np.log10(bins[nonzero])
t = np.log10(freqs[nonzero])

# %%
from sklearn.linear_model import LinearRegression, Ridge

powerlaw1 = LinearRegression().fit(x[:, np.newaxis], t)
powerlaw2 = Ridge().fit(x[:, np.newaxis], t)
powerlaw3 = Ridge(alpha=10.0).fit(x[:, np.newaxis], t)

coef_a1, coef_b1 = 10**powerlaw1.intercept_, powerlaw1.coef_[0]
print(f"Linear Reg: y = {coef_a1:.2f} * x^{coef_b1:.2f}")
coef_a2, coef_b2 = 10**powerlaw2.intercept_, powerlaw2.coef_[0]
print(f"Ridge: y = {coef_a2:.2f} * x^{coef_b2:.2f}")
coef_a3, coef_b3 = 10**powerlaw3.intercept_, powerlaw3.coef_[0]
print(f"Ridge, alpha=10: y = {coef_a3:.2f} * x^{coef_b3:.2f}")
# Out:
# Linear Reg: y = 6931237.61 * x^-2.28
# Ridge: y = 3109447.63 * x^-2.14
# Ridge, alpha=10: y = 37625.05 * x^-1.40

# %%
ax=sns.lineplot(x=x, y=t, color='blue', label='Training data')
sns.lineplot(x=x, y=powerlaw1.predict(x[:, np.newaxis]), ax=ax, color='green', label='Linear Reg')
sns.lineplot(x=x, y=powerlaw2.predict(x[:, np.newaxis]), ax=ax, color='orange', label='Ridge')
sns.lineplot(x=x, y=powerlaw3.predict(x[:, np.newaxis]), ax=ax, color='red', label='Ridge, alpha=10')

ax.legend()

# %%
coef_a, coef_b = 10**powerlaw3.intercept_, powerlaw3.coef_[0]
ts = coef_a * (xs ** coef_b)
# Out:
# /tmp/ipykernel_1560/3414088482.py:2: RuntimeWarning: divide by zero encountered in power
#   ts = coef_a * (xs ** coef_b)

# %%
ax = sns.histplot(poiCheckinCounts.checkins)
sns.lineplot(x=xs, y=ts, ax=ax, color='orange')
# sns.lineplot(x=x, y=powerlaw.predict(x[:, np.newaxis]), color='orange')
# Out:
# <Axes: xlabel='checkins', ylabel='Count'>

# %%
sns.lineplot(x=xs, y=np.log(ts), color='orange')
# Out:
# <Axes: >
